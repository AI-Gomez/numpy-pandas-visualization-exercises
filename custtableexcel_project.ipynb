# %%
import pandas as pd
df = pd.read_csv(r'/Users/cryptobandido/Desktop/projectcusttable.csv')
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df.sort_values(['monthly_tenure', 'has_churned'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ec88e98f370d> in <module>
# ----> 1 df.sort_values(['monthly_tenure', 'has_churned'])
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# -> 4920             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4921             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4922             indexer = ensure_platform_int(indexer)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7049 non-null   object
#  1   gender                  7049 non-null   object
#  2   is_senior_citizen       7049 non-null   int64
#  3   partner                 7049 non-null   object
#  4   dependents              7049 non-null   object
#  5   phone_service           7049 non-null   int64
#  6   phone_desc              7049 non-null   object
#  7   internet_service        7049 non-null   int64
#  8   internet_desc           7049 non-null   object
#  9   services_rendered       7049 non-null   object
#  10  contract_type           7049 non-null   int64
#  11  contract_desc           7049 non-null   object
#  12  payment_type            7049 non-null   object
#  13  monthly_charges         7049 non-null   float64
# ...

# %%
df.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges  Monthly Tenure  partner_dependants  \
# count      7049.000000    7038.000000     7049.000000         7049.000000
# mean         64.747014    2283.043883       32.374805            1.266704
# std          30.099460    2266.521984       24.596637            1.274510
# ...

# %%
df.sort_values('churn')
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 4378  6173-GOLSU    Male                  1     Yes         No              2
# 4376  6171-ZTVYB    Male                  0     Yes         No              2
# 4375  6169-PPETC    Male                  0     Yes        Yes              1
# 4374  6169-PGNCD  Female                  0      No         No              1
# ...          ...     ...                ...     ...        ...            ...
# 4814  6771-XWBDM  Female                  0     Yes         No              2
# 4815  6772-KSATR    Male                  0      No         No              2
# 4818  6776-TLWOI    Male                  0      No         No              1
# 4866  6857-VWJDT  Female                  0      No         No              2
# 5022  7055-VKGDA    Male                  0      No         No              1
#
# ...

# %%
contract_churn = df.groupby('contract_desc')['churn'].value_counts()
print(contract_churn)

service_churn = df.groupby('services_rendered')['churn'].value_counts()
print(service_churn)
# Out:
# contract_desc   churn
# 1 Year          No       1310
#                 Yes       166
# 2 Year          No       1649
#                 Yes        48
# Month-to-Month  No       2220
#                 Yes      1656
# Name: churn, dtype: int64
# services_rendered  churn
# has both           No       3251
#                    Yes      1586
# has internet       No       1416
#                    Yes       113
# has phone          No        512
#                    Yes       171
# Name: churn, dtype: int64

# %%
paymenttype_churn = df.groupby('payment_type')['churn'].value_counts()
print(paymenttype_churn)

gender_churn = df.groupby('gender')['churn'].value_counts()
print(gender_churn)
# Out:
# payment_type               churn
# Bank transfer (automatic)  No       1289
#                            Yes       259
# Credit card (automatic)    No       1292
#                            Yes       232
# Electronic check           No       1294
#                            Yes      1071
# Mailed check               No       1304
#                            Yes       308
# Name: churn, dtype: int64
# gender  churn
# Female  No       2551
#         Yes       940
# Male    No       2628
#         Yes       930
# Name: churn, dtype: int64

# %%
df.groupby('payment_type')['churn'].value_counts()
# Out:
# payment_type               churn
# Bank transfer (automatic)  No       1289
#                            Yes       259
# Credit card (automatic)    No       1292
#                            Yes       232
# Electronic check           No       1294
#                            Yes      1071
# Mailed check               No       1304
#                            Yes       308
# Name: churn, dtype: int64

# %%
import seaborn as sns
sns.distplot(hascon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b12ccfedf1d0> in <module>
#       1 import seaborn as sns
# ----> 2 sns.distplot(hascon)
#
# NameError: name 'hascon' is not defined

# %%
df.groupby('services_rendered')['churn'].value_counts()
# Out:
# services_rendered  churn
# has both           No       3251
#                    Yes      1586
# has internet       No        512
#                    Yes       171
# has phone          No       1416
#                    Yes       113
# Name: churn, dtype: int64

# %%
df.monthly_tenure.hist()

# %%
df.monthly_charges.value_counts()
# Out:
# 20.05     61
# 19.85     45
# 19.95     44
# 19.70     44
# 19.90     44
#           ..
# 66.75      1
# 68.55      1
# 116.30     1
# 23.65      1
# 40.45      1
# Name: monthly_charges, Length: 1585, dtype: int64

# %%
df.groupby('has_churned')['services_rendered'].value_counts()
# Out:
# has_churned  services_rendered
# False        has both             3251
#              has internet         1416
#              has phone             512
# True         has both             1586
#              has phone             171
#              has internet          113
# Name: services_rendered, dtype: int64

# %%
df.groupby('is_senior_citizen')['churn'].value_counts()
# Out:
# is_senior_citizen  churn
# 0                  No       4513
#                    Yes      1394
# 1                  No        666
#                    Yes       476
# Name: churn, dtype: int64

# %%
df.groupby('monthly_charges')['payment_type'].value_counts()
# Out:
# monthly_charges  payment_type
# 18.25            Credit card (automatic)      1
# 18.40            Bank transfer (automatic)    1
# 18.55            Credit card (automatic)      1
# 18.70            Mailed check                 2
# 18.75            Bank transfer (automatic)    1
#                                              ..
# 118.35           Bank transfer (automatic)    1
# 118.60           Electronic check             1
#                  Mailed check                 1
# 118.65           Electronic check             1
# 118.75           Bank transfer (automatic)    1
# Name: payment_type, Length: 3519, dtype: int64
