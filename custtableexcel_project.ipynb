# %%
import pandas as pd
df = pd.read_csv(r'/Users/cryptobandido/Desktop/projectcusttable.csv')
df
# Out:
#       gender partner dependents  phone_service         phone_desc  \
# 0     Female     Yes        Yes              1           One Line
# 1       Male      No         No              2  Two or More Lines
# 2       Male      No         No              1           One Line
# 3       Male     Yes         No              1           One Line
# 4     Female     Yes         No              1           One Line
# ...      ...     ...        ...            ...                ...
# 7044  Female      No         No              1           One Line
# 7045    Male     Yes         No              2  Two or More Lines
# 7046    Male      No         No              1           One Line
# 7047    Male     Yes        Yes              1           One Line
# 7048    Male     Yes        Yes              0   No Phone Service
#
#       internet_service        internet_desc services_rendered  contract_type  \
# 0                    1                  DSL          has both              1
# 1                    1          Fiber Optic          has both              0
# 2                    2                  DSL          has both              0
# 3                    2                  DSL          has both              0
# 4                    2                  DSL          has both              0
# ...                ...                  ...               ...            ...
# 7044                 1                  DSL          has both              1
# 7045                 2          Fiber Optic          has both              0
# 7046                 1                  DSL          has both              0
# 7047                 1                  DSL          has both              2
# 7048                 1  No Internet Service      has internet              2
#
#        contract_desc  ... monthly_tenure  is_female  has_churned has_phone  \
# 0             1 Year  ...            9.0       True        False      True
# 1     Month-to-Month  ...            9.0      False        False      True
# 2     Month-to-Month  ...            4.0      False         True      True
# 3     Month-to-Month  ...           13.0      False         True      True
# 4     Month-to-Month  ...            3.0       True         True      True
# ...              ...  ...            ...        ...          ...       ...
# 7044          1 Year  ...           13.0       True        False      True
# 7045  Month-to-Month  ...           22.0      False         True      True
# 7046  Month-to-Month  ...            2.0      False        False      True
# 7047          2 Year  ...           68.0      False        False      True
# 7048          2 Year  ...           63.0      False        False     False
#
#       has_internet  has_phone_and_internet  partner_dependants  start_date  \
# 0             True                    True                   3  2019-11-30
# 1             True                    True                   0  2019-11-30
# 2             True                    True                   0  2020-04-28
# 3             True                    True                   2  2019-08-02
# 4             True                    True                   2  2020-05-28
# ...            ...                     ...                 ...         ...
# 7044          True                    True                   0  2019-08-02
# 7045          True                    True                   2  2018-11-05
# 7046          True                    True                   0  2020-06-27
# 7047          True                    True                   3  2015-01-25
# 7048          True                   False                   3  2015-06-24
#
#       monthly_charges1  Does_it_match?
# 0               590.40           False
# 1               539.10           False
# 2               295.60           False
# 3              1274.00           False
# 4               251.70           False
# ...                ...             ...
# 7044            716.95           False
# 7045           1872.20           False
# 7046            100.60           False
# 7047           4613.80           False
# 7048           3717.00           False
#
# [7049 rows x 24 columns]

# %%
df.sort_values(['monthly_tenure', 'has_churned'])
# Out:
#       gender partner dependents  phone_service         phone_desc  \
# 945   Female     Yes        Yes              0   No Phone Service
# 1731  Female     Yes        Yes              1           One Line
# 1906    Male      No        Yes              2  Two or More Lines
# 2025    Male     Yes        Yes              1           One Line
# 2176    Male      No        Yes              1           One Line
# ...      ...     ...        ...            ...                ...
# 2748  Female     Yes         No              1           One Line
# 4268    Male     Yes         No              2  Two or More Lines
# 5038  Female      No         No              1           One Line
# 5835  Female     Yes         No              2  Two or More Lines
# 4167  Female      No        Yes              1           One Line
#
#       internet_service        internet_desc services_rendered  contract_type  \
# 945                  1  No Internet Service      has internet              2
# 1731                 0                  DSL         has phone              2
# 1906                 1          Fiber Optic          has both              2
# 2025                 0                  DSL         has phone              1
# 2176                 0                  DSL         has phone              2
# ...                ...                  ...               ...            ...
# 2748                 0                  DSL         has phone              2
# 4268                 0          Fiber Optic         has phone              2
# 5038                 0                  DSL         has phone              2
# 5835                 0          Fiber Optic         has phone              2
# 4167                 0                  DSL         has phone              2
#
#      contract_desc  ... monthly_tenure  is_female  has_churned has_phone  \
# 945         2 Year  ...            0.0       True        False     False
# 1731        2 Year  ...            0.0       True        False      True
# 1906        2 Year  ...            0.0      False        False      True
# 2025        1 Year  ...            0.0      False        False      True
# 2176        2 Year  ...            0.0      False        False      True
# ...            ...  ...            ...        ...          ...       ...
# 2748        2 Year  ...           77.0       True        False      True
# 4268        2 Year  ...           77.0      False        False      True
# 5038        2 Year  ...           77.0       True        False      True
# 5835        2 Year  ...           77.0       True        False      True
# 4167        2 Year  ...           79.0       True        False      True
#
#       has_internet  has_phone_and_internet  partner_dependants  start_date  \
# 945           True                   False                   3  2020-08-26
# 1731         False                   False                   3  2020-08-26
# 1906          True                    True                   1  2020-08-26
# 2025         False                   False                   3  2020-08-26
# 2176         False                   False                   1  2020-08-26
# ...            ...                     ...                 ...         ...
# 2748         False                   False                   2  2014-04-30
# 4268         False                    True                   2  2014-04-30
# 5038         False                   False                   0  2014-04-30
# 5835         False                    True                   2  2014-04-30
# 4167         False                   False                   1  2014-03-01
#
#       monthly_charges1  Does_it_match?
# 945               0.00            True
# 1731              0.00            True
# 1906              0.00            True
# 2025              0.00            True
# 2176              0.00            True
# ...                ...             ...
# 2748           1493.80           False
# 4268           1936.55           False
# 5038           1559.25           False
# 5835           2002.00           False
# 4167           1560.25           False
#
# [7049 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gender                  7049 non-null   object
#  1   partner                 7049 non-null   object
#  2   dependents              7049 non-null   object
#  3   phone_service           7049 non-null   int64
#  4   phone_desc              7049 non-null   object
#  5   internet_service        7049 non-null   int64
#  6   internet_desc           7049 non-null   object
#  7   services_rendered       7049 non-null   object
#  8   contract_type           7049 non-null   int64
#  9   contract_desc           7049 non-null   object
#  10  payment_type            7049 non-null   object
#  11  monthly_charges         7049 non-null   float64
#  12  total_charges           7038 non-null   float64
#  13  churn                   7049 non-null   object
#  14  monthly_tenure          7049 non-null   float64
#  15  is_female               7049 non-null   bool
#  16  has_churned             7049 non-null   bool
#  17  has_phone               7049 non-null   bool
#  18  has_internet            7049 non-null   bool
#  19  has_phone_and_internet  7049 non-null   bool
#  20  partner_dependants      7049 non-null   int64
#  21  start_date              7049 non-null   object
#  22  monthly_charges1        7049 non-null   float64
#  23  Does_it_match?          7049 non-null   bool
# dtypes: bool(6), float64(4), int64(4), object(10)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        phone_service  internet_service  contract_type  monthly_charges  \
# count    7049.000000       7049.000000    7049.000000      7049.000000
# mean        1.324585          1.222585       0.690878        64.747014
# std         0.642709          0.779068       0.833757        30.099460
# min         0.000000          0.000000       0.000000        18.250000
# 25%         1.000000          1.000000       0.000000        35.450000
# 50%         1.000000          1.000000       0.000000        70.350000
# 75%         2.000000          2.000000       1.000000        89.850000
# max         2.000000          2.000000       2.000000       118.750000
#
#        total_charges  monthly_tenure  partner_dependants  monthly_charges1
# count    7038.000000     7049.000000         7049.000000       7049.000000
# mean     2283.043883       32.374805            1.266704       2279.237778
# std      2266.521984       24.596637            1.274510       2266.944333
# min        18.800000        0.000000            0.000000          0.000000
# 25%       401.587500        9.000000            0.000000        396.400000
# 50%      1397.100000       29.000000            1.000000       1392.000000
# 75%      3793.775000       55.000000            2.000000       3784.500000
# max      8684.800000       79.000000            3.000000       8717.200000

# %%
df.sort_values('churn')
# Out:
#       gender partner dependents  phone_service         phone_desc  \
# 0     Female     Yes        Yes              1           One Line
# 4378    Male     Yes         No              2  Two or More Lines
# 4376    Male     Yes         No              2  Two or More Lines
# 4375    Male     Yes        Yes              1           One Line
# 4374  Female      No         No              1           One Line
# ...      ...     ...        ...            ...                ...
# 4814  Female     Yes         No              2  Two or More Lines
# 4815    Male      No         No              2  Two or More Lines
# 4818    Male      No         No              1           One Line
# 4866  Female      No         No              2  Two or More Lines
# 5022    Male      No         No              1           One Line
#
#       internet_service internet_desc services_rendered  contract_type  \
# 0                    1           DSL          has both              1
# 4378                 2   Fiber Optic          has both              0
# 4376                 1   Fiber Optic          has both              0
# 4375                 0           DSL         has phone              2
# 4374                 1           DSL          has both              2
# ...                ...           ...               ...            ...
# 4814                 2   Fiber Optic          has both              0
# 4815                 2   Fiber Optic          has both              0
# 4818                 0           DSL         has phone              0
# 4866                 2   Fiber Optic          has both              0
# 5022                 2           DSL          has both              1
#
#        contract_desc  ... monthly_tenure  is_female  has_churned has_phone  \
# 0             1 Year  ...            9.0       True        False      True
# 4378  Month-to-Month  ...           64.0      False        False      True
# 4376  Month-to-Month  ...           44.0      False        False      True
# 4375          2 Year  ...           37.0      False        False      True
# 4374          2 Year  ...           56.0       True        False      True
# ...              ...  ...            ...        ...          ...       ...
# 4814  Month-to-Month  ...           57.0       True         True      True
# 4815  Month-to-Month  ...            1.0      False         True      True
# 4818  Month-to-Month  ...            3.0      False         True      True
# 4866  Month-to-Month  ...            1.0       True         True      True
# 5022          1 Year  ...           54.0      False         True      True
#
#       has_internet  has_phone_and_internet  partner_dependants  start_date  \
# 0             True                    True                   3  2019-11-30
# 4378          True                    True                   2  2015-05-25
# 4376          True                    True                   2  2017-01-14
# 4375         False                   False                   3  2017-08-12
# 4374          True                    True                   0  2016-01-20
# ...            ...                     ...                 ...         ...
# 4814          True                    True                   2  2015-12-21
# 4815          True                    True                   0  2020-07-27
# 4818         False                   False                   0  2020-05-28
# 4866          True                    True                   0  2020-07-27
# 5022          True                    True                   0  2016-03-20
#
#       monthly_charges1  Does_it_match?
# 0               590.40           False
# 4378           6057.60           False
# 4376           2915.00           False
# 4375            758.50           False
# 4374           4160.80           False
# ...                ...             ...
# 4814           5956.50           False
# 4815             81.70            True
# 4818             59.55           False
# 4866             95.65            True
# 5022           5691.60           False
#
# [7049 rows x 24 columns]

# %%
contract_churn = df.groupby('contract_desc')['churn'].value_counts()
print(contract_churn)

service_churn = df.groupby('services_rendered')['churn'].value_counts()
print(service_churn)
# Out:
# contract_desc   churn
# 1 Year          No       1310
#                 Yes       166
# 2 Year          No       1649
#                 Yes        48
# Month-to-Month  No       2220
#                 Yes      1656
# Name: churn, dtype: int64
# services_rendered  churn
# has both           No       3251
#                    Yes      1586
# has internet       No        512
#                    Yes       171
# has phone          No       1416
#                    Yes       113
# Name: churn, dtype: int64

# %%
paymenttype_churn = df.groupby('payment_type')['churn'].value_counts()
print(paymenttype_churn)

gender_churn = df.groupby('gender')['churn'].value_counts()
print(gender_churn)
# Out:
# payment_type               churn
# Bank transfer (automatic)  No       1289
#                            Yes       259
# Credit card (automatic)    No       1292
#                            Yes       232
# Electronic check           No       1294
#                            Yes      1071
# Mailed check               No       1304
#                            Yes       308
# Name: churn, dtype: int64
# gender  churn
# Female  No       2551
#         Yes       940
# Male    No       2628
#         Yes       930
# Name: churn, dtype: int64

# %%
df.groupby('payment_type')['churn'].value_counts()
# Out:
# payment_type               churn
# Bank transfer (automatic)  No       1289
#                            Yes       259
# Credit card (automatic)    No       1292
#                            Yes       232
# Electronic check           No       1294
#                            Yes      1071
# Mailed check               No       1304
#                            Yes       308
# Name: churn, dtype: int64

# %%
import seaborn as sns
sns.distplot(hascon)

# %%
df.groupby('services_rendered')['churn'].value_counts()
# Out:
# services_rendered  churn
# has both           No       3251
#                    Yes      1586
# has internet       No        512
#                    Yes       171
# has phone          No       1416
#                    Yes       113
# Name: churn, dtype: int64

# %%
df.monthly_tenure.hist()

# %%
df.monthly_charges.value_counts()
# Out:
# 20.05     61
# 19.85     45
# 19.95     44
# 19.70     44
# 19.90     44
#           ..
# 66.75      1
# 68.55      1
# 116.30     1
# 23.65      1
# 40.45      1
# Name: monthly_charges, Length: 1585, dtype: int64

# %%
df.groupby('has_churned')['services_rendered'].value_counts()
# Out:
# has_churned  services_rendered
# False        has both             3251
#              has phone            1416
#              has internet          512
# True         has both             1586
#              has internet          171
#              has phone             113
# Name: services_rendered, dtype: int64
